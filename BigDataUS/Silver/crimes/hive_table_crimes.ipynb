# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
# que bases de dados é que temos
spark.sql(
    """
    SHOW DATABASES
    """
).show()
# Out:
# +--------------+
# |     namespace|
# +--------------+
# |americancrimes|
# |       default|
# |       economy|
# |      politics|
# +--------------+

# %%
spark.sql(
    """
    SHOW TABLES FROM americancrimes
    """
).show()
# Out:
# +--------------+----------------+-----------+
# |      database|       tableName|isTemporary|
# +--------------+----------------+-----------+
# |americancrimes|civillian_deaths|      false|
# +--------------+----------------+-----------+

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS americancrimes.crimes
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE americancrimes.crimes (
        violent_crime INT,
        property_crime INT,
        state STRING,
        state_abb STRING
    )
    STORED AS PARQUET
    PARTITIONED BY (
        year DATE
    )
    LOCATION 'hdfs://hdfs-nn:9000/warehouse/americancrimes.db/crimes/'
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    SHOW TABLES FROM americancrimes
    """
).show()
# Out:
# +--------------+----------------+-----------+
# |      database|       tableName|isTemporary|
# +--------------+----------------+-----------+
# |americancrimes|civillian_deaths|      false|
# |americancrimes|          crimes|      false|
# +--------------+----------------+-----------+

# %%
spark.sql(
    """
    SELECT *
    FROM americancrimes.crimes
    """
).show()
# Out:
# +-------------+--------------+-----+---------+----+
# |violent_crime|property_crime|state|state_abb|year|
# +-------------+--------------+-----+---------+----+
# +-------------+--------------+-----+---------+----+

# %%
spark.sql(
    """
    DESCRIBE FORMATTED americancrimes.crimes
    """
).toPandas()
# Out:
#                         col_name  \
# 0                  violent_crime
# 1                 property_crime
# 2                          state
# 3                      state_abb
# 4                           year
# 5        # Partition Information
# 6                     # col_name
# 7                           year
# 8
# 9   # Detailed Table Information
# 10                      Database
# 11                         Table
# 12                         Owner
# 13                  Created Time
# 14                   Last Access
# 15                    Created By
# 16                          Type
# 17                      Provider
# 18              Table Properties
# 19                      Location
# 20                 Serde Library
# 21                   InputFormat
# 22                  OutputFormat
# 23            Storage Properties
# 24            Partition Provider
#
#                                             data_type  comment
# 0                                                 int     None
# 1                                                 int     None
# 2                                              string     None
# 3                                              string     None
# 4                                                date     None
# 5
# 6                                           data_type  comment
# 7                                                date     None
# 8
# 9
# 10                                     americancrimes
# 11                                             crimes
# 12                                             jovyan
# 13                       Fri Jun 11 01:25:36 UTC 2021
# 14                                            UNKNOWN
# 15                                        Spark 3.1.1
# 16                                           EXTERNAL
# 17                                               hive
# 18                 [transient_lastDdlTime=1623374736]
# 19  hdfs://hdfs-nn:9000/warehouse/americancrimes.d...
# 20  org.apache.hadoop.hive.ql.io.parquet.serde.Par...
# 21  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 22  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 23                           [serialization.format=1]
# 24                                            Catalog

# %%
# recover partitions is needed so that the Hive Metastore (Catalog)
# is updated. Otherwise Hive and the querying engines do not know
# that there are new parittions in the partitioned table.
spark.catalog.recoverPartitions("americancrimes.crimes")

spark.sql(
    """
    SELECT *
    FROM americancrimes.crimes
    where year = "2011-01-01"
    """
).show()
# Out:
# +-------------+--------------+-----+---------+----+
# |violent_crime|property_crime|state|state_abb|year|
# +-------------+--------------+-----+---------+----+
# +-------------+--------------+-----+---------+----+

# %%
spark.stop()
